# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\eshop\datascience\my_env\lib\site-packages (6.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\eshop\datascience\my_env\lib\site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in c:\users\eshop\datascience\my_env\lib\site-packages (from plotly) (25.0)
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\eshop\datascience\my_env\lib\site-packages (1.2.0)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\eshop\datascience\my_env\lib\site-packages (from kaleido) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\eshop\datascience\my_env\lib\site-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\eshop\datascience\my_env\lib\site-packages (from kaleido) (3.11.8)
# Requirement already satisfied: packaging in c:\users\eshop\datascience\my_env\lib\site-packages (from kaleido) (25.0)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\eshop\datascience\my_env\lib\site-packages (from kaleido) (2.4.0)
# Requirement already satisfied: platformdirs>=4.3.6 in c:\users\eshop\datascience\my_env\lib\site-packages (from choreographer>=1.1.1->kaleido) (4.5.1)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\eshop\datascience\my_env\lib\site-packages (from choreographer>=1.1.1->kaleido) (4.1.1)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\eshop\datascience\my_env\lib\site-packages (from pytest-timeout>=2.4.0->kaleido) (9.0.3)
# Requirement already satisfied: colorama>=0.4 in c:\users\eshop\datascience\my_env\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\eshop\datascience\my_env\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\eshop\datascience\my_env\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\eshop\datascience\my_env\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "png"

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.line(tips['total_bill'])

# %%
px.bar(tips.groupby('day')['tip'].mean())
# Out:
# C:\Users\ESHOP\AppData\Local\Temp\ipykernel_10696\2286189767.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   px.bar(tips.groupby('day')['tip'].mean())

# %%
px.scatter(tips, x='total_bill', y='tip')

# %%
px.box(tips, x='total_bill', y='day')
